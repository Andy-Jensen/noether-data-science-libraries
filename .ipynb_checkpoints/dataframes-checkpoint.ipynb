# %%
from pydataset import data
import pandas as pd
import numpy as np

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
#Create a column named passing_english that indicates whether each student has a passing grade in english.
df['passing_english'] = df.english > 70
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
#Sort the english grades by the passing_english column. How are duplicates handled?
df.sort_values(by = 'passing_english')
#duplicates are sorted ascending by the index
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
#Sort the english grades first by passing_english and then by student name. 
#All the students that are failing english should be first, and within the students that are 
#failing english they should be ordered alphabetically. 
#The same should be true for the students passing english. 
#(Hint: you can pass a list to the .sort_values method)

df.sort_values(by = ['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 11     Alan    92       62       72            False          75.33
# 8    Albert    92       62       87            False          80.33
# 7     Marie    93       63       90            False          82.00
# 6    Thomas    82       64       81            False          75.67
# 4       Ada    77       92       98             True          89.00
# 3     Billy    98       96       88             True          94.00
# 10    Isaac    92       99       93             True          94.67
# 1      Jane    88       79       67             True          78.00
# 5      John    79       76       93             True          82.67
# 9   Richard    69       80       94             True          81.00
# 0     Sally    62       85       80             True          75.67
# 2     Suzie    94       74       95             True          87.67

# %%
#Sort the english grades first by passing_english, and then by the actual english grade, 
#similar to how we did in the last step.
df.sort_values(by = ['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 8    Albert    92       62       87            False          80.33
# 11     Alan    92       62       72            False          75.33
# 7     Marie    93       63       90            False          82.00
# 6    Thomas    82       64       81            False          75.67
# 2     Suzie    94       74       95             True          87.67
# 5      John    79       76       93             True          82.67
# 1      Jane    88       79       67             True          78.00
# 9   Richard    69       80       94             True          81.00
# 0     Sally    62       85       80             True          75.67
# 4       Ada    77       92       98             True          89.00
# 3     Billy    98       96       88             True          94.00
# 10    Isaac    92       99       93             True          94.67

# %%
#Calculate each students overall grade and add it as a column on the dataframe. 
#The overall grade is the average of the math, english, and reading grades.
df['overall_grade'] = round((df.math + df.english + df.reading) / 3, 2)
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True          75.67
# 1      Jane    88       79       67             True          78.00
# 2     Suzie    94       74       95             True          87.67
# 3     Billy    98       96       88             True          94.00
# 4       Ada    77       92       98             True          89.00
# 5      John    79       76       93             True          82.67
# 6    Thomas    82       64       81            False          75.67
# 7     Marie    93       63       90            False          82.00
# 8    Albert    92       62       87            False          80.33
# 9   Richard    69       80       94             True          81.00
# 10    Isaac    92       99       93             True          94.67
# 11     Alan    92       62       72            False          75.33

# %% [markdown]
# mpg

# %%
mpg = data('mpg')

# %%
#How many rows and columns are there?
mpg.shape
# Out:
# (234, 11)

# %%
#What are the data types of each column?
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
#Summarize the dataframe with .info and .describe
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#Rename the cty column to city.
new_mpg = mpg.rename(columns = {'cty': 'city'})
new_mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %%
#Rename the hwy column to highway.
newer_mpg = new_mpg.rename(columns = {'hwy': 'highway'})
newer_mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
#Do any cars have better city mileage than highway mileage?
newer_mpg[newer_mpg.city > newer_mpg.highway].count()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# city            0
# highway         0
# fl              0
# class           0
# dtype: int64

# %%
#Create a column named mileage_difference this column should contain the 
#difference between highway and city mileage for each car.
newer_mpg['milage_difference'] = newer_mpg.highway - newer_mpg.city
newer_mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  milage_difference
# ...

# %%
#Which car (or cars) has the highest mileage difference?
newer_mpg[newer_mpg.milage_difference == max(newer_mpg.milage_difference)]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  milage_difference
# 107  c  subcompact                 12
# 223  d  subcompact                 12

# %%
#Which compact class car has the lowest highway mileage? The best?
(
    newer_mpg[newer_mpg['class'] == 'compact'].sort_values(by = 'milage_difference').tail(1),
    newer_mpg[newer_mpg['class'] == 'compact'].sort_values(by = 'milage_difference').head(1)
)
# Out:
# (  manufacturer model  displ  year  cyl     trans drv  city  highway fl  \
#  1         audi    a4    1.8  1999    4  auto(l5)   f    18       29  p
#
#       class  milage_difference
#  1  compact                 11  ,
#      manufacturer        model  displ  year  cyl     trans drv  city  highway  \
#  170       subaru  impreza awd    2.5  2008    4  auto(s4)   4    20       25
#
#      fl    class  milage_difference
#  170  p  compact                  5  )

# %%
newer_mpg[newer_mpg['class'] == 'compact'].sort_values(by = 'milage_difference').tail(1)
# Out:
#   manufacturer model  displ  year  cyl     trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4  auto(l5)   f    18       29  p
#
#      class  milage_difference
# 1  compact                 11

# %%
newer_mpg[newer_mpg['class'] == 'compact'].sort_values(by = 'milage_difference').head(1)
# Out:
#     manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 170       subaru  impreza awd    2.5  2008    4  auto(s4)   4    20       25
#
#     fl    class  milage_difference
# 170  p  compact                  5

# %%
#Create a column named average_mileage that is the mean of the city and highway mileage.
newer_mpg['average_mileage'] = (newer_mpg.city + newer_mpg.highway) / 2
newer_mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
#Which dodge car has the best average mileage? The worst?
newer_mpg[newer_mpg['manufacturer'] == 'dodge'].sort_values(by = 'average_mileage').tail(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  milage_difference  average_mileage
# 38  r  minivan                  6             21.0

# %%
newer_mpg[newer_mpg['manufacturer'] == 'dodge'].sort_values(by = 'average_mileage').head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  milage_difference  average_mileage
# 70       12  e  pickup                  3             10.5

# %%
mammals = data('Mammals')

# %%
#How many rows and columns are there?
mammals.shape
# Out:
# (107, 4)

# %%
#What are the data types?
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
#Summarize the dataframe with .info and .describe
mammals.info
# Out:
# <bound method DataFrame.info of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
#What is the the weight of the fastest animal?
mammals[mammals.speed == max(mammals.speed)].sort_values(by = 'weight')
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
#What is the overal percentage of specials?
len(mammals[mammals.specials == True]) / len(mammals) * 100
# Out:
# 9.345794392523365

# %%
#How many animals are hoppers that are above the median speed? What percentage is this?
round(len(mammals[mammals.specials == True]) / len(mammals), 5 * 100)
mammal_median = np.median(mammals.speed)

fast_bois = mammals[mammals.speed > mammal_median]
fast_bois[fast_bois.hoppers == True]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
len(fast_bois[fast_bois.hoppers == True]) / len(mammals) * 100
# Out:
# 6.5420560747663545
